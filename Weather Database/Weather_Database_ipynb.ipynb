# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
# Import the API key.
from config import weather_api_key
import requests

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 641

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import datetime
from datetime import datetime

# Import the datetime module from the datetime library
import time
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []


# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp= city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M^%S')
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Weather Description": city_weather_description,
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hasaki
# Processing Record 2 of Set 1 | provideniya
# Processing Record 3 of Set 1 | eureka
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | plettenberg bay
# Processing Record 6 of Set 1 | karratha
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | ancud
# Processing Record 11 of Set 1 | arraial do cabo
# Processing Record 12 of Set 1 | pichayevo
# Processing Record 13 of Set 1 | college
# Processing Record 14 of Set 1 | hameenlinna
# Processing Record 15 of Set 1 | okhotsk
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | galle
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | raduzhnyy
# Processing Record 21 of Set 1 | chokurdakh
# Processing Record 22 of Set 1 | starobesheve
# Processing Record 23 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | half moon bay
# Processing Record 30 of Set 1 | tinaogan
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | hinton
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | hay river
# Processing Record 35 of Set 1 | airai
# Processing Record 36 of Set 1 | tondano
# Processing Record 37 of Set 1 | ahipara
# Processing Record 38 of Set 1 | labuhan
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | buri
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | leh
# Processing Record 43 of Set 1 | sawtell
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | puerto madryn
# Processing Record 46 of Set 1 | viareggio
# Processing Record 47 of Set 1 | mancheral
# Processing Record 48 of Set 1 | tomatlan
# Processing Record 49 of Set 1 | vanse
# Processing Record 50 of Set 1 | souillac
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | mogocha
# Processing Record 3 of Set 2 | leningradskiy
# Processing Record 4 of Set 2 | soc trang
# Processing Record 5 of Set 2 | coihaique
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | touros
# Processing Record 10 of Set 2 | roebourne
# Processing Record 11 of Set 2 | portales
# Processing Record 12 of Set 2 | pangnirtung
# Processing Record 13 of Set 2 | xuddur
# Processing Record 14 of Set 2 | den helder
# Processing Record 15 of Set 2 | fuyang
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | deputatskiy
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | nouadhibou
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | mwingi
# Processing Record 25 of Set 2 | vaini
# Processing Record 26 of Set 2 | torbay
# Processing Record 27 of Set 2 | toktogul
# Processing Record 28 of Set 2 | flin flon
# Processing Record 29 of Set 2 | guanica
# Processing Record 30 of Set 2 | rio cuarto
# Processing Record 31 of Set 2 | bairnsdale
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | salalah
# Processing Record 34 of Set 2 | nemuro
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | shimoda
# Processing Record 37 of Set 2 | ugoofaaru
# Processing Record 38 of Set 2 | palmer
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | pemba
# Processing Record 41 of Set 2 | dukstas
# Processing Record 42 of Set 2 | yumen
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 2 | coleraine
# Processing Record 46 of Set 2 | bozeman
# Processing Record 47 of Set 2 | yeppoon
# Processing Record 48 of Set 2 | barcelos
# Processing Record 49 of Set 2 | astana
# Processing Record 50 of Set 2 | apatou
# Processing Record 1 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 3 | kudahuvadhoo
# Processing Record 3 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | muros
# Processing Record 6 of Set 3 | chara
# Processing Record 7 of Set 3 | alexandria
# Processing Record 8 of Set 3 | san cristobal
# Processing Record 9 of Set 3 | ajdabiya
# Processing Record 10 of Set 3 | flinders
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | castro
# Processing Record 13 of Set 3 | golynki
# Processing Record 14 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 3 | sorland
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | north myrtle beach
# Processing Record 18 of Set 3 | saint anthony
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | geraldton
# Processing Record 21 of Set 3 | mataura
# Processing Record 22 of Set 3 | hokitika
# Processing Record 23 of Set 3 | takoradi
# Processing Record 24 of Set 3 | belyy yar
# Processing Record 25 of Set 3 | barrow
# Processing Record 26 of Set 3 | solnechnyy
# Processing Record 27 of Set 3 | hualmay
# Processing Record 28 of Set 3 | ocampo
# Processing Record 29 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 3 | huilong
# Processing Record 31 of Set 3 | thompson
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | predivinsk
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | talnakh
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | yulara
# Processing Record 41 of Set 3 | inuvik
# Processing Record 42 of Set 3 | banjar
# Processing Record 43 of Set 3 | port alfred
# Processing Record 44 of Set 3 | datong
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | cherskiy
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | taltal
# Processing Record 49 of Set 3 | vao
# Processing Record 50 of Set 3 | qui nhon
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | manaus
# Processing Record 3 of Set 4 | hobart
# Processing Record 4 of Set 4 | pokosnoye
# Processing Record 5 of Set 4 | busselton
# Processing Record 6 of Set 4 | sinnamary
# Processing Record 7 of Set 4 | iskateley
# Processing Record 8 of Set 4 | paldiski
# Processing Record 9 of Set 4 | turukhansk
# Processing Record 10 of Set 4 | perth
# Processing Record 11 of Set 4 | te anau
# Processing Record 12 of Set 4 | abis
# Processing Record 13 of Set 4 | coulihaut
# City not found. Skipping...
# Processing Record 14 of Set 4 | kaeo
# Processing Record 15 of Set 4 | huaicheng
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | kajaani
# Processing Record 18 of Set 4 | lavrentiya
# Processing Record 19 of Set 4 | havre-saint-pierre
# Processing Record 20 of Set 4 | belmonte
# Processing Record 21 of Set 4 | havelock
# Processing Record 22 of Set 4 | hofn
# Processing Record 23 of Set 4 | pacific grove
# Processing Record 24 of Set 4 | djenne
# Processing Record 25 of Set 4 | faanui
# Processing Record 26 of Set 4 | los llanos de aridane
# Processing Record 27 of Set 4 | puerto escondido
# Processing Record 28 of Set 4 | madera
# Processing Record 29 of Set 4 | yaguara
# Processing Record 30 of Set 4 | hurricane
# Processing Record 31 of Set 4 | saskylakh
# Processing Record 32 of Set 4 | tasiilaq
# Processing Record 33 of Set 4 | tilichiki
# Processing Record 34 of Set 4 | portland
# Processing Record 35 of Set 4 | butaritari
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | saldanha
# Processing Record 38 of Set 4 | khromtau
# Processing Record 39 of Set 4 | kesennuma
# City not found. Skipping...
# Processing Record 40 of Set 4 | montepuez
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | saint-augustin
# Processing Record 43 of Set 4 | xining
# Processing Record 44 of Set 4 | brae
# Processing Record 45 of Set 4 | sioux lookout
# Processing Record 46 of Set 4 | djambala
# Processing Record 47 of Set 4 | krasnoyarskiy
# Processing Record 48 of Set 4 | plouzane
# Processing Record 49 of Set 4 | soma
# Processing Record 50 of Set 4 | klaksvik
# Processing Record 1 of Set 5 | kahului
# Processing Record 2 of Set 5 | pangody
# Processing Record 3 of Set 5 | jumla
# Processing Record 4 of Set 5 | skelleftea
# Processing Record 5 of Set 5 | grevesmuhlen
# Processing Record 6 of Set 5 | carnarvon
# Processing Record 7 of Set 5 | ilulissat
# Processing Record 8 of Set 5 | broome
# Processing Record 9 of Set 5 | haines junction
# Processing Record 10 of Set 5 | lucapa
# Processing Record 11 of Set 5 | belaya gora
# Processing Record 12 of Set 5 | pithiviers
# Processing Record 13 of Set 5 | luwuk
# Processing Record 14 of Set 5 | narsaq
# Processing Record 15 of Set 5 | grand gaube
# Processing Record 16 of Set 5 | tawnat
# City not found. Skipping...
# Processing Record 17 of Set 5 | mehamn
# Processing Record 18 of Set 5 | husavik
# Processing Record 19 of Set 5 | dunedin
# Processing Record 20 of Set 5 | saint-pierre
# Processing Record 21 of Set 5 | kununurra
# Processing Record 22 of Set 5 | bolitoc
# Processing Record 23 of Set 5 | pallasovka
# Processing Record 24 of Set 5 | rio gallegos
# Processing Record 25 of Set 5 | collie
# Processing Record 26 of Set 5 | wahiawa
# Processing Record 27 of Set 5 | norman wells
# Processing Record 28 of Set 5 | la ronge
# Processing Record 29 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 5 | suluq
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | sao joao da barra
# Processing Record 33 of Set 5 | buala
# Processing Record 34 of Set 5 | riyadh
# Processing Record 35 of Set 5 | hami
# Processing Record 36 of Set 5 | urzicuta
# Processing Record 37 of Set 5 | watrous
# Processing Record 38 of Set 5 | clyde river
# Processing Record 39 of Set 5 | constitucion
# Processing Record 40 of Set 5 | tall kayf
# Processing Record 41 of Set 5 | santa cruz verapaz
# Processing Record 42 of Set 5 | mattru
# Processing Record 43 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 44 of Set 5 | novyy urengoy
# Processing Record 45 of Set 5 | sakakah
# Processing Record 46 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 5 | orlovskiy
# Processing Record 48 of Set 5 | russell
# Processing Record 49 of Set 5 | mascote
# Processing Record 50 of Set 5 | katsuura
# Processing Record 1 of Set 6 | kodiak
# Processing Record 2 of Set 6 | komsomolskiy
# Processing Record 3 of Set 6 | port blair
# Processing Record 4 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 6 | dingle
# Processing Record 6 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 6 | naze
# Processing Record 8 of Set 6 | taungdwingyi
# Processing Record 9 of Set 6 | zhigansk
# Processing Record 10 of Set 6 | ampanihy
# Processing Record 11 of Set 6 | lagoa
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 6 | saint george
# Processing Record 15 of Set 6 | manado
# Processing Record 16 of Set 6 | snezhnogorsk
# Processing Record 17 of Set 6 | ndele
# Processing Record 18 of Set 6 | huarmey
# Processing Record 19 of Set 6 | south milwaukee
# Processing Record 20 of Set 6 | kavaratti
# Processing Record 21 of Set 6 | roros
# Processing Record 22 of Set 6 | egvekinot
# Processing Record 23 of Set 6 | tselinnoye
# Processing Record 24 of Set 6 | togitsu
# Processing Record 25 of Set 6 | mendoza
# Processing Record 26 of Set 6 | chulman
# Processing Record 27 of Set 6 | namatanai
# Processing Record 28 of Set 6 | port hardy
# Processing Record 29 of Set 6 | mangrol
# Processing Record 30 of Set 6 | redcliffe
# Processing Record 31 of Set 6 | harrisonburg
# Processing Record 32 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 6 | bambanglipuro
# Processing Record 35 of Set 6 | bethel
# Processing Record 36 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 6 | kiruna
# Processing Record 38 of Set 6 | phan thiet
# Processing Record 39 of Set 6 | canutama
# Processing Record 40 of Set 6 | bukama
# Processing Record 41 of Set 6 | ambilobe
# Processing Record 42 of Set 6 | oranjemund
# Processing Record 43 of Set 6 | cidreira
# Processing Record 44 of Set 6 | gamba
# Processing Record 45 of Set 6 | asosa
# Processing Record 46 of Set 6 | vestmannaeyjar
# Processing Record 47 of Set 6 | saint-francois
# Processing Record 48 of Set 6 | tabou
# Processing Record 49 of Set 6 | baghdad
# Processing Record 50 of Set 6 | diamantino
# Processing Record 1 of Set 7 | gigmoto
# Processing Record 2 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 7 | fortuna
# Processing Record 4 of Set 7 | talara
# Processing Record 5 of Set 7 | batemans bay
# Processing Record 6 of Set 7 | nizwa
# Processing Record 7 of Set 7 | broken hill
# Processing Record 8 of Set 7 | aripuana
# Processing Record 9 of Set 7 | surt
# Processing Record 10 of Set 7 | isangel
# Processing Record 11 of Set 7 | pokoynoye
# Processing Record 12 of Set 7 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 13 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 7 | nelidovo
# Processing Record 15 of Set 7 | alta floresta
# Processing Record 16 of Set 7 | krasnomayskiy
# Processing Record 17 of Set 7 | fairbanks
# Processing Record 18 of Set 7 | totness
# Processing Record 19 of Set 7 | yashkul
# Processing Record 20 of Set 7 | tiarei
# Processing Record 21 of Set 7 | cancun
# Processing Record 22 of Set 7 | kuryk
# Processing Record 23 of Set 7 | belle fourche
# Processing Record 24 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 7 | zaozerne
# Processing Record 26 of Set 7 | raudeberg
# Processing Record 27 of Set 7 | laguna
# Processing Record 28 of Set 7 | tual
# Processing Record 29 of Set 7 | igarka
# Processing Record 30 of Set 7 | paraiso
# Processing Record 31 of Set 7 | ponta do sol
# Processing Record 32 of Set 7 | charters towers
# Processing Record 33 of Set 7 | cayenne
# Processing Record 34 of Set 7 | catuday
# Processing Record 35 of Set 7 | atambua
# Processing Record 36 of Set 7 | noumea
# Processing Record 37 of Set 7 | vrangel
# Processing Record 38 of Set 7 | mgandu
# Processing Record 39 of Set 7 | korla
# Processing Record 40 of Set 7 | mount isa
# Processing Record 41 of Set 7 | olinda
# Processing Record 42 of Set 7 | presidencia roque saenz pena
# Processing Record 43 of Set 7 | antalaha
# Processing Record 44 of Set 7 | urfa
# City not found. Skipping...
# Processing Record 45 of Set 7 | mareeba
# Processing Record 46 of Set 7 | ketchikan
# Processing Record 47 of Set 7 | juneau
# Processing Record 48 of Set 7 | chifeng
# Processing Record 49 of Set 7 | opuwo
# Processing Record 50 of Set 7 | ostrovnoy
# Processing Record 1 of Set 8 | kumluca
# Processing Record 2 of Set 8 | brockville
# Processing Record 3 of Set 8 | oriximina
# Processing Record 4 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 5 of Set 8 | tucuman
# Processing Record 6 of Set 8 | carutapera
# Processing Record 7 of Set 8 | caravelas
# Processing Record 8 of Set 8 | quatre cocos
# Processing Record 9 of Set 8 | selfoss
# Processing Record 10 of Set 8 | rach gia
# Processing Record 11 of Set 8 | stabat
# Processing Record 12 of Set 8 | seoul
# Processing Record 13 of Set 8 | smirnykh
# Processing Record 14 of Set 8 | kamaishi
# Processing Record 15 of Set 8 | sitka
# Processing Record 16 of Set 8 | qandala
# Processing Record 17 of Set 8 | waingapu
# Processing Record 18 of Set 8 | beringovskiy
# Processing Record 19 of Set 8 | tura
# Processing Record 20 of Set 8 | kaohsiung
# Processing Record 21 of Set 8 | pitimbu
# Processing Record 22 of Set 8 | qasigiannguit
# Processing Record 23 of Set 8 | san-pedro
# Processing Record 24 of Set 8 | tonj
# Processing Record 25 of Set 8 | northport
# Processing Record 26 of Set 8 | bosaso
# Processing Record 27 of Set 8 | bairiki
# Processing Record 28 of Set 8 | poum
# Processing Record 29 of Set 8 | coquimbo
# Processing Record 30 of Set 8 | mandalgovi
# Processing Record 31 of Set 8 | shahrud
# Processing Record 32 of Set 8 | ler
# Processing Record 33 of Set 8 | turkan
# Processing Record 34 of Set 8 | nortelandia
# Processing Record 35 of Set 8 | conde
# Processing Record 36 of Set 8 | guelengdeng
# City not found. Skipping...
# Processing Record 37 of Set 8 | zurrieq
# Processing Record 38 of Set 8 | rocha
# Processing Record 39 of Set 8 | goundam
# Processing Record 40 of Set 8 | alofi
# Processing Record 41 of Set 8 | belem de sao francisco
# Processing Record 42 of Set 8 | candawaga
# City not found. Skipping...
# Processing Record 43 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 44 of Set 8 | sorong
# Processing Record 45 of Set 8 | hovd
# Processing Record 46 of Set 8 | svetlogorsk
# Processing Record 47 of Set 8 | mufulira
# Processing Record 48 of Set 8 | hamilton
# Processing Record 49 of Set 8 | luderitz
# Processing Record 50 of Set 8 | aras
# Processing Record 1 of Set 9 | bartica
# Processing Record 2 of Set 9 | tiruvottiyur
# City not found. Skipping...
# Processing Record 3 of Set 9 | ust-kuyga
# Processing Record 4 of Set 9 | byron bay
# Processing Record 5 of Set 9 | maumere
# Processing Record 6 of Set 9 | bahile
# Processing Record 7 of Set 9 | pisco
# Processing Record 8 of Set 9 | pontes e lacerda
# Processing Record 9 of Set 9 | olovyannaya
# Processing Record 10 of Set 9 | ossora
# Processing Record 11 of Set 9 | berlevag
# Processing Record 12 of Set 9 | longonjo
# Processing Record 13 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 9 | mombris
# Processing Record 15 of Set 9 | guamuchil
# Processing Record 16 of Set 9 | stornoway
# Processing Record 17 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 9 | merauke
# Processing Record 19 of Set 9 | romny
# Processing Record 20 of Set 9 | sayyan
# Processing Record 21 of Set 9 | zyryanka
# Processing Record 22 of Set 9 | ust-omchug
# Processing Record 23 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 9 | maningrida
# Processing Record 25 of Set 9 | zhicheng
# Processing Record 26 of Set 9 | ginir
# Processing Record 27 of Set 9 | bambous virieux
# Processing Record 28 of Set 9 | bintulu
# Processing Record 29 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 9 | dubbo
# Processing Record 32 of Set 9 | sipe sipe
# Processing Record 33 of Set 9 | port-cartier
# Processing Record 34 of Set 9 | abu kamal
# Processing Record 35 of Set 9 | semporna
# Processing Record 36 of Set 9 | kuytun
# Processing Record 37 of Set 9 | arrecife
# Processing Record 38 of Set 9 | price
# Processing Record 39 of Set 9 | puerto del rosario
# Processing Record 40 of Set 9 | mchinji
# Processing Record 41 of Set 9 | leshukonskoye
# Processing Record 42 of Set 9 | soyo
# Processing Record 43 of Set 9 | tikrit
# Processing Record 44 of Set 9 | ouadda
# Processing Record 45 of Set 9 | ambon
# Processing Record 46 of Set 9 | west bay
# Processing Record 47 of Set 9 | nantucket
# Processing Record 48 of Set 9 | faya
# Processing Record 49 of Set 9 | benjamin constant
# Processing Record 50 of Set 9 | mbanza-ngungu
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | novobiryusinskiy
# Processing Record 3 of Set 10 | ulladulla
# Processing Record 4 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 10 | tarakan
# Processing Record 6 of Set 10 | atbasar
# Processing Record 7 of Set 10 | karema
# Processing Record 8 of Set 10 | mitsamiouli
# Processing Record 9 of Set 10 | san vicente
# Processing Record 10 of Set 10 | aksu
# Processing Record 11 of Set 10 | gold coast
# Processing Record 12 of Set 10 | huaiyin
# Processing Record 13 of Set 10 | port lincoln
# Processing Record 14 of Set 10 | morahalom
# Processing Record 15 of Set 10 | chemal
# Processing Record 16 of Set 10 | jan kempdorp
# Processing Record 17 of Set 10 | cap malheureux
# Processing Record 18 of Set 10 | el sauzal
# Processing Record 19 of Set 10 | kloulklubed
# Processing Record 20 of Set 10 | paramonga
# Processing Record 21 of Set 10 | ornskoldsvik
# Processing Record 22 of Set 10 | wadi maliz
# Processing Record 23 of Set 10 | puerto baquerizo moreno
# Processing Record 24 of Set 10 | camacha
# Processing Record 25 of Set 10 | ouegoa
# Processing Record 26 of Set 10 | shihezi
# Processing Record 27 of Set 10 | srivardhan
# Processing Record 28 of Set 10 | cabanas
# Processing Record 29 of Set 10 | puerto colombia
# Processing Record 30 of Set 10 | manggar
# Processing Record 31 of Set 10 | belen
# Processing Record 32 of Set 10 | benton harbor
# Processing Record 33 of Set 10 | tumsar
# Processing Record 34 of Set 10 | skjervoy
# Processing Record 35 of Set 10 | kingaroy
# Processing Record 36 of Set 10 | eirunepe
# Processing Record 37 of Set 10 | belgrade
# Processing Record 38 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 10 | shaunavon
# Processing Record 40 of Set 10 | fukue
# Processing Record 41 of Set 10 | kerki
# City not found. Skipping...
# Processing Record 42 of Set 10 | porto novo
# Processing Record 43 of Set 10 | nome
# Processing Record 44 of Set 10 | nioro
# Processing Record 45 of Set 10 | gurun
# Processing Record 46 of Set 10 | glubokoe
# City not found. Skipping...
# Processing Record 47 of Set 10 | damaturu
# Processing Record 48 of Set 10 | kavieng
# Processing Record 49 of Set 10 | hornepayne
# Processing Record 50 of Set 10 | margate
# Processing Record 1 of Set 11 | goderich
# Processing Record 2 of Set 11 | marsh harbour
# Processing Record 3 of Set 11 | pierre
# Processing Record 4 of Set 11 | luzhou
# Processing Record 5 of Set 11 | phon
# Processing Record 6 of Set 11 | hukuntsi
# Processing Record 7 of Set 11 | lola
# Processing Record 8 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 9 of Set 11 | mailsi
# Processing Record 10 of Set 11 | mana
# Processing Record 11 of Set 11 | sisimiut
# Processing Record 12 of Set 11 | samarai
# Processing Record 13 of Set 11 | pacifica
# Processing Record 14 of Set 11 | atar
# Processing Record 15 of Set 11 | magistralnyy
# Processing Record 16 of Set 11 | bubaque
# Processing Record 17 of Set 11 | teguldet
# Processing Record 18 of Set 11 | domoni
# Processing Record 19 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 11 | evensk
# Processing Record 21 of Set 11 | ha tinh
# Processing Record 22 of Set 11 | ucluelet
# Processing Record 23 of Set 11 | port augusta
# Processing Record 24 of Set 11 | orlik
# Processing Record 25 of Set 11 | ardakan
# Processing Record 26 of Set 11 | shingu
# Processing Record 27 of Set 11 | codrington
# Processing Record 28 of Set 11 | betki
# City not found. Skipping...
# Processing Record 29 of Set 11 | shahr-e babak
# Processing Record 30 of Set 11 | lasa
# Processing Record 31 of Set 11 | limulunga
# Processing Record 32 of Set 11 | aksarka
# Processing Record 33 of Set 11 | tessalit
# Processing Record 34 of Set 11 | bukachacha
# Processing Record 35 of Set 11 | amravati
# Processing Record 36 of Set 11 | eganville
# Processing Record 37 of Set 11 | san quintin
# Processing Record 38 of Set 11 | ridgecrest
# Processing Record 39 of Set 11 | gisborne
# Processing Record 40 of Set 11 | comodoro rivadavia
# Processing Record 41 of Set 11 | puerto carreno
# Processing Record 42 of Set 11 | hammerfest
# Processing Record 43 of Set 11 | bandarbeyla
# Processing Record 44 of Set 11 | lakes entrance
# Processing Record 45 of Set 11 | rairangpur
# Processing Record 46 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 47 of Set 11 | tevriz
# Processing Record 48 of Set 11 | vinh
# Processing Record 49 of Set 11 | biak
# Processing Record 50 of Set 11 | baykit
# Processing Record 1 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 2 of Set 12 | imeni poliny osipenko
# Processing Record 3 of Set 12 | la macarena
# Processing Record 4 of Set 12 | andenes
# Processing Record 5 of Set 12 | fort payne
# Processing Record 6 of Set 12 | yerbogachen
# Processing Record 7 of Set 12 | aykhal
# Processing Record 8 of Set 12 | alihe
# Processing Record 9 of Set 12 | cockburn town
# Processing Record 10 of Set 12 | tsnori
# Processing Record 11 of Set 12 | lorengau
# Processing Record 12 of Set 12 | itarema
# Processing Record 13 of Set 12 | pinheiro machado
# Processing Record 14 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 12 | lakhi
# Processing Record 16 of Set 12 | wajima
# Processing Record 17 of Set 12 | nyurba
# Processing Record 18 of Set 12 | turinsk
# Processing Record 19 of Set 12 | vredendal
# Processing Record 20 of Set 12 | tibagi
# Processing Record 21 of Set 12 | marathon
# Processing Record 22 of Set 12 | taoudenni
# Processing Record 23 of Set 12 | slonim
# Processing Record 24 of Set 12 | bucerias
# Processing Record 25 of Set 12 | necochea
# Processing Record 26 of Set 12 | lesosibirsk
# Processing Record 27 of Set 12 | yinchuan
# Processing Record 28 of Set 12 | nanortalik
# Processing Record 29 of Set 12 | quezon
# Processing Record 30 of Set 12 | alice springs
# Processing Record 31 of Set 12 | ljungby
# Processing Record 32 of Set 12 | santa maria
# Processing Record 33 of Set 12 | develi
# Processing Record 34 of Set 12 | krasnoselkup
# Processing Record 35 of Set 12 | almeirim
# Processing Record 36 of Set 12 | panzhihua
# Processing Record 37 of Set 12 | krasnousolskiy
# City not found. Skipping...
# Processing Record 38 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 12 | bauchi
# Processing Record 40 of Set 12 | piacabucu
# Processing Record 41 of Set 12 | sobolevo
# Processing Record 42 of Set 12 | kyra
# Processing Record 43 of Set 12 | mayumba
# Processing Record 44 of Set 12 | usinsk
# Processing Record 45 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 12 | jiazi
# Processing Record 47 of Set 12 | yar-sale
# Processing Record 48 of Set 12 | chiang khong
# Processing Record 49 of Set 12 | svetlaya
# Processing Record 50 of Set 12 | north bend
# Processing Record 1 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 13 | malasin
# Processing Record 3 of Set 13 | wixom
# Processing Record 4 of Set 13 | zalantun
# Processing Record 5 of Set 13 | khorinsk
# Processing Record 6 of Set 13 | marienburg
# Processing Record 7 of Set 13 | phichit
# Processing Record 8 of Set 13 | arecibo
# Processing Record 9 of Set 13 | shelburne
# Processing Record 10 of Set 13 | paracuru
# Processing Record 11 of Set 13 | oeiras
# Processing Record 12 of Set 13 | lompoc
# Processing Record 13 of Set 13 | raga
# Processing Record 14 of Set 13 | upington
# Processing Record 15 of Set 13 | saryozek
# Processing Record 16 of Set 13 | hambantota
# Processing Record 17 of Set 13 | kirakira
# Processing Record 18 of Set 13 | vyyezdnoye
# Processing Record 19 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 20 of Set 13 | bud
# Processing Record 21 of Set 13 | whitehorse
# Processing Record 22 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 13 | lac du bonnet
# Processing Record 24 of Set 13 | dujuma
# City not found. Skipping...
# Processing Record 25 of Set 13 | fort nelson
# Processing Record 26 of Set 13 | sungaipenuh
# Processing Record 27 of Set 13 | kisangani
# Processing Record 28 of Set 13 | batticaloa
# Processing Record 29 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 13 | danielskuil
# Processing Record 31 of Set 13 | virtsu
# Processing Record 32 of Set 13 | novita
# Processing Record 33 of Set 13 | littleton
# Processing Record 34 of Set 13 | daru
# Processing Record 35 of Set 13 | padilla
# Processing Record 36 of Set 13 | baruun-urt
# Processing Record 37 of Set 13 | boa vista
# Processing Record 38 of Set 13 | chalons-en-champagne
# Processing Record 39 of Set 13 | adrar
# Processing Record 40 of Set 13 | marovoay
# Processing Record 41 of Set 13 | paita
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 587

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hasaki  35.7333  140.8333     74.21        57          99
# 1      Provideniya  64.3833 -173.3000     32.36        69          20
# 2           Eureka  40.8021 -124.1637     66.18        64          17
# 3  Plettenberg Bay -34.0527   23.3716     70.50        56         100
# 4         Karratha -20.7377  116.8463     77.61        23          57
# 5           Atuona  -9.8000 -139.0333     76.75        70          11
# 6       Georgetown   5.4112  100.3354     80.53        87          20
# 7            Ancud -41.8697  -73.8203     46.78        77          13
# 8  Arraial Do Cabo -22.9661  -42.0278     73.26        88          20
# 9        Pichayevo  53.2363   42.2032     49.87        88         100
#
#    Wind Speed Country Weather Description
# 0       22.75      JP     overcast clouds
# 1       11.18      RU          few clouds
# 2        3.00      US          few clouds
# 3        4.68      ZA     overcast clouds
# 4        9.08      AU       broken clouds
# 5       14.65      PF          few clouds
# 6        3.44      MY        thunderstorm
# 7        6.69      CL          few clouds
# 8        4.61      BR          few clouds
# 9       12.77      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = list(city_data_df.columns)
new_column_order
# Out:
# ['City',
#  'Lat',
#  'Lng',
#  'Max Temp',
#  'Humidity',
#  'Cloudiness',
#  'Wind Speed',
#  'Country',
#  'Weather Description']

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",
                    "Cloudiness", "Wind Speed",  "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hasaki      JP  35.7333  140.8333     74.21        57          99
# 1      Provideniya      RU  64.3833 -173.3000     32.36        69          20
# 2           Eureka      US  40.8021 -124.1637     66.18        64          17
# 3  Plettenberg Bay      ZA -34.0527   23.3716     70.50        56         100
# 4         Karratha      AU -20.7377  116.8463     77.61        23          57
# 5           Atuona      PF  -9.8000 -139.0333     76.75        70          11
# 6       Georgetown      MY   5.4112  100.3354     80.53        87          20
# 7            Ancud      CL -41.8697  -73.8203     46.78        77          13
# 8  Arraial Do Cabo      BR -22.9661  -42.0278     73.26        88          20
# 9        Pichayevo      RU  53.2363   42.2032     49.87        88         100
#
#    Wind Speed Weather Description
# 0       22.75     overcast clouds
# 1       11.18          few clouds
# 2        3.00          few clouds
# 3        4.68     overcast clouds
# 4        9.08       broken clouds
# 5       14.65          few clouds
# 6        3.44        thunderstorm
# 7        6.69          few clouds
# 8        4.61          few clouds
# 9       12.77     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
df = pd.DataFrame(city_data)
df.dtypes
# Out:
# City                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Country                 object
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
weather_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(weather_file, index_label="City_ID")
